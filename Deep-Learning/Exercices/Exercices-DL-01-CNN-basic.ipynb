# %% [markdown]
# # Image — MNIST avec préparation et data augmentation
#
# ### Objectif
#
# **Comprendre :**
#
# - pipeline image DL
#
# - préparation des données
#
# - data augmentation
#
# - entraînement d’un CNN simple

# %% [markdown]
# ## Étape 1 — Exploration des données

# %% [markdown]
# ### Dataset :

# %%
from tensorflow.keras.datasets import mnist

# %% [markdown]
# **Questions :**
#
# - Quelle est la forme des images ?
#
# - Combien y a-t-il de classes ?
#
# - Combien d’exemples par classe ?
#
# - Afficher quelques images.

# %% [markdown]
# ## Étape 2 — Préparation des données

# %% [markdown]
# **Guidage :**
#
# 1. Convertir en float
#
# 2. Normaliser

# %%
X = X / 255.0

# %% [markdown]
# 3. Ajouter la dimension canal

# %%
X = X.reshape(-1, 28, 28, 1)

# %% [markdown]
# **Questions :**
#
# - Pourquoi ajouter une dimension canal ?

# %% [markdown]
# ## Étape 3 — One-hot encoding

# %% [markdown]
# **Transformer les labels.**

# %%
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# **Question :**
#
# - Pourquoi utiliser one-hot avec softmax ?

# %% [markdown]
# ## Étape 4 — Data augmentation

# %% [markdown]
# **Utiliser :**
#
# - ImageDataGenerator

# %%
datagen = ImageDataGenerator(
    rotation_range=10,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1
)

# %% [markdown]
# **Objectif pédagogique :**
#
# - Faire comprendre que l’on simule de nouvelles données.
#
# **Questions :**
#
# - Pourquoi l’augmentation améliore la généralisation ?
#
# - Quels types de transformations sont raisonnables pour MNIST ?

# %% [markdown]
# ## Étape 5 — CNN simple

# %% [markdown]
# ### Architecture :
#
# ```py
#     Conv2D(32, (3,3), activation="relu")
#     MaxPooling2D()
#     Conv2D(64, (3,3), activation="relu")
#     MaxPooling2D()
#     Flatten()
#     Dense(128, activation="relu")
#     Dense(10, activation="softmax")
# ```

# %% [markdown]
# ## Étape 6 — Comparaison

# %% [markdown]
# **Faire 2 entraînements :**
#
# - sans augmentation
#
# - avec augmentation
#
# **Comparer :**
#
# - accuracy
#
# - overfitting
