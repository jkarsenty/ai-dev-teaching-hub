# %% [markdown]
# # Fashion MNIST avec pipeline complet

# %% [markdown]
# ## Étape 1 — Nettoyage des données
#
# **Steps :**
#
# - normaliser
#
# - ajouter dimension canal

# %% [markdown]
# ## Étape 2 — Visualisation
#
# **Afficher :**
#
# - plusieurs images
#
# - classes correspondantes
#
# **Question :**
#
# - Pourquoi ce dataset est-il plus difficile que MNIST ?

# %% [markdown]
# ## Étape 3 — Data augmentation
#
# **Proposition :**
#
# ```py
#     ImageDataGenerator(
#         rotation_range=15,
#         zoom_range=0.1,
#         horizontal_flip=True
#     )
# ```
#
# **Question :**
#
# - Pourquoi `horizontal_flip` est acceptable ici mais pas sur MNIST ?

# %% [markdown]
# ## Étape 4 — CNN
#
# **Architecture légèrement plus profonde.**

# %% [markdown]
# ## Étape 5 — Analyse
#
# **Analyser :**
#
# - confusion matrix
#
# - classes les plus difficiles
